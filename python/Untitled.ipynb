# %%
import pytest
import numpy as np
from scipy.sparse import csc_matrix

import l0learn

N = 50

# %%
x = np.random.random(size=(N, N))
x_sparse = csc_matrix(x)
y = np.random.random(size=(N,))

# %%
model_fit = l0learn.fit(x, y, intercept=False)

# %%
model_fit
# Out:
# FitModel({'loss': 'SquaredError', 'intercept': False, 'penalty': 'L0'})

# %%
lambda_grid = [[10, 12] , [13, 10]]

# %%
[[float(i) for i in lst] for lst in lambda_grid]
# Out:
# [[10.0, 12.0], [13.0, 10.0]]
